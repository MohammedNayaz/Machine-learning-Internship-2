# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedNayaz/Machine-learning-Internship-2/blob/master/Python_Pandas2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas Package

# %% [markdown]
# ##Pandas.Series

# %%
#Create empty series
import pandas as pd
s = pd.Series()
print (s)
# Out:
# Series([], dtype: float64)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Create a Series from ndarray
import pandas as pd
import numpy as np 
data = np.array(['a','b','c','d']) 
s = pd.Series(data) 
print (s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data,index=[100,101,102,103]) 
print (s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
#Create a Series from dict
import numpy as np
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data)
print (s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
#example 2
import pandas as pd
import numpy as np
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data,index=['b','c','d','a'])
print (s)
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
#Create a Series from Scalar
import pandas as pd
import numpy as np
s = pd.Series(5, index=[0, 1, 2, 3])
print (s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
#Create a Series from Scalar
import pandas as pd
import numpy as np
s = pd.Series(5, index=['a','b','c','d','e'])
print (s)
# Out:
# a    5
# b    5
# c    5
# d    5
# e    5
# dtype: int64

# %%
#Accessing Data from Series with Position
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e']) 
#retrieve the first element
print (s[0])
# Out:
# 1

# %%
s[:]
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s[:2]
# Out:
# a    1
# b    2
# dtype: int64

# %%
#example 2
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
#retrieve the first three element
print (s[:3])
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
#Example 3
import pandas as pd 
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e']) 
#retrieve the last three element
print (s[-3:])
# Out:
# c    3
# d    4
# e    5
# dtype: int64

# %%
#Retrieve Data Using Label (Index)
import pandas as pd
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e']) #retrieve multiple elements 
print (s[['a','c','d']])
# Out:
# a    1
# c    3
# d    4
# dtype: int64

# %%
print([['a','b','d']])
# Out:
# [['a', 'b', 'd']]

# %%
print(s[['a','b','d']])
# Out:
# a    1
# b    2
# d    4
# dtype: int64

# %% [markdown]
# ##Pandas.Dataframe

# %%
#Create an Empty DataFrame
import pandas as pd
df = pd.DataFrame()
print (df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Create a DataFrame from Lists
import pandas as pd
data = [1,2,3,4,5] 
df = pd.DataFrame(data) 
print (df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
#Example 2
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df=pd.DataFrame(data,columns=['Name','Age'])
print (df)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
#Example 3
import pandas as pd
data = [['Alex',10],['Bob',12.5],['Clarke',13]]
df=pd.DataFrame(data,columns=['Name','Age'],dtype=float)
print (df)
# Out:
#      Name   Age
# 0    Alex  10.0
# 1     Bob  12.5
# 2  Clarke  13.0

# %%
#Create a DataFrame from Dict of ndarrays / Lists
import pandas as pd
data={'Name':['Tom','Jack','Steve','Ricky'],'Age':[28,34,29,42]} 
df = pd.DataFrame(data) 
print (df)
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %%
#Ex-2
import pandas as pd
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
df=pd.DataFrame(data,index=['rank1','rank2','rank3','rank4']) 
print (df)
# Out:
#         Name  Age
# rank1    Tom   28
# rank2   Jack   34
# rank3  Steve   29
# rank4  Ricky   42

# %%
#Create a DataFrame from Dict of Series
import pandas as pd
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])} 
df = pd.DataFrame(d) 
print (df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
#Create a DataFrame from Dict of Series
import pandas as pd
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])} 
df = pd.DataFrame(d) 
print (df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
#Create a DataFrame from Dict of Series
import pandas as pd
x = {'one' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']), 'two' : pd.Series([5, 6, 7, 8, 9, 10], index=['a', 'b', 'c', 'd'])} 
df = pd.DataFrame(x) 
print (df)
# Out:
#    one  two
# a    1    1
# b    2    2
# c    3    3
# d    4    4

# %%
#Create a DataFrame from Dict of Series
import pandas as pd
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']), 'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd']), 'three' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])} 
df = pd.DataFrame(d) 
print (df)
# Out:
#    one  two  three
# a  1.0    1      1
# b  2.0    2      2
# c  3.0    3      3
# d  NaN    4      4

# %% [markdown]
# ##Pandas Series.to_numpy()

# %%
import pandas as pd
# reading the csv   
data = pd.read_csv("teams.csv")
data.dropna(inplace = True) 
data
# Out:
#                           team1
# 0                 Pune Warriors
# 1         Kolkata Knight Riders
# 2              Rajasthan Royals
# 3          Kochi Tuskers Kerala
# 4                 Gujarat Lions
# 5           Chennai Super Kings
# 6       Rising Pune Supergiants
# 7              Delhi Daredevils
# 8               Deccan Chargers
# 9                Delhi Capitals
# 10               Mumbai Indians
# 11          Sunrisers Hyderabad
# 12       Rising Pune Supergiant
# 13  Royal Challengers Bangalore
# 14              Kings XI Punjab

# %%
import pandas as pd
# reading the csv   
data = pd.read_csv("matches.csv")
data.dropna(inplace = True) 
data
# Out:
#         id    Season  ...               umpire2                  umpire3
# 636   7894  IPL-2018  ...       A Nanda Kishore           Anil Chaudhary
# 637   7895  IPL-2018  ...  K Ananthapadmanabhan              Nitin Menon
# 638   7896  IPL-2018  ...          A.D Deshmukh                   S Ravi
# 639   7897  IPL-2018  ...       Vineet Kulkarni                 O Nandan
# 640   7898  IPL-2018  ...        Chris Gaffaney          A Nanda Kishore
# ..     ...       ...  ...                   ...                      ...
# 750  11346  IPL-2019  ...         C Shamshuddin           Bruce Oxenford
# 751  11347  IPL-2019  ...              O Nandan                   S Ravi
# 752  11412  IPL-2019  ...           Nitin Menon                Ian Gould
# 754  11414  IPL-2019  ...        Bruce Oxenford  Chettithody Shamshuddin
# 755  11415  IPL-2019  ...             Ian Gould              Nigel Llong
#
# [118 rows x 18 columns]

# %%
# creating series form weight column 
df = pd.Series(data['toss_winner'].head()) 
df
# Out:
# 636      Chennai Super Kings
# 637          Kings XI Punjab
# 638    Kolkata Knight Riders
# 639      Sunrisers Hyderabad
# 640      Chennai Super Kings
# Name: toss_winner, dtype: object

# %%
# using to_numpy() function 
print(df.to_numpy())
print(df)
# Out:
# ['Chennai Super Kings' 'Kings XI Punjab' 'Kolkata Knight Riders'
#  'Sunrisers Hyderabad' 'Chennai Super Kings']
# 636      Chennai Super Kings
# 637          Kings XI Punjab
# 638    Kolkata Knight Riders
# 639      Sunrisers Hyderabad
# 640      Chennai Super Kings
# Name: toss_winner, dtype: object

# %%
# creating series form weight column 
df = pd.Series(data['win_by_wickets'].head()) 
df
# Out:
# 636    1
# 637    6
# 638    4
# 639    9
# 640    5
# Name: win_by_wickets, dtype: int64

# %%
# using to_numpy() function 
print(df.to_numpy())
print(df)
# Out:
# [1 6 4 9 5]
# 636    1
# 637    6
# 638    4
# 639    9
# 640    5
# Name: win_by_wickets, dtype: int64

# %%
import pandas as pd
ser = pd.Series(pd.date_range('2000', periods=2, tz="CET"))
ser
# Out:
# 0   2000-01-01 00:00:00+01:00
# 1   2000-01-02 00:00:00+01:00
# dtype: datetime64[ns, CET]

# %%
ser.to_numpy(dtype=object)
# Out:
# array([Timestamp('2000-01-01 00:00:00+0100', tz='CET', freq='D'),
#        Timestamp('2000-01-02 00:00:00+0100', tz='CET', freq='D')],
#       dtype=object)

# %% [markdown]
# ##Pandas Dataframe.to_numpy()

# %%
import pandas as pd
# reading the csv   
data = pd.read_csv("matches.csv")
data.dropna(inplace = True) 
# creating DataFrame form weight column 
df = pd.DataFrame(data['player_of_match'].head()) 
df
# Out:
#     player_of_match
# 636        DJ Bravo
# 637        KL Rahul
# 638       SP Narine
# 639        S Dhawan
# 640     SW Billings

# %%
import pandas as pd
# reading the csv   
data = pd.read_csv("f500.csv")
data.dropna(inplace = True) 
data
# Out:
#                             company  rank  ...  employees  total_stockholder_equity
# 0                           Walmart     1  ...    2300000                     77798
# 1                        State Grid     2  ...     926067                    209456
# 2                     Sinopec Group     3  ...     713288                    106523
# 3          China National Petroleum     4  ...    1512048                    301893
# 4                      Toyota Motor     5  ...     364445                    157210
# ..                              ...   ...  ...        ...                       ...
# 495  Teva Pharmaceutical Industries   496  ...      56960                     33337
# 496        New China Life Insurance   497  ...      54378                      8507
# 497       Wm. Morrison Supermarkets   498  ...      77210                      5111
# 498                             TUI   499  ...      66779                      3006
# ...

# %%
import pandas as pd
# reading the csv   
data = pd.read_csv("f500.csv")
data.dropna(inplace = True) 
# creating DataFrame form weight column 
df = pd.DataFrame(data['revenues'].head()) 
df
# Out:
#    revenues
# 0    485873
# 1    315199
# 2    267518
# 3    262573
# 4    254694

# %%
# using to_numpy() function 
print(df.to_numpy())
# Out:
# [[485873]
#  [315199]
#  [267518]
#  [262573]
#  [254694]]

# %%
#ex-2

import pandas as pd
# read csv file   
data = pd.read_csv("f500.csv")
data.dropna(inplace = True)
# creating DataFrame form weight column 
df = pd.DataFrame(data['assets'].head())
# providing dtype 
print(df.to_numpy(dtype ='float32'))
# Out:
# [[198825.]
#  [489838.]
#  [310726.]
#  [585619.]
#  [437575.]]

# %%
import numpy as np
import pandas as pd
np_array = np.random.rand(12,3)
print("Original Numpy array:")
print(np_array)
print("Type: ",type(np_array))
df = pd.DataFrame(np.random.rand(12,3),columns=['A','B','C'])
print("\nPanda's DataFrame: ")
print(df)
print("Type: ",type(df))
# Out:
# Original Numpy array:
# [[0.42993883 0.88212169 0.83942244]
#  [0.29441756 0.43159656 0.15675084]
#  [0.38615385 0.95550975 0.43730514]
#  [0.47082204 0.19819627 0.41568184]
#  [0.5171153  0.49607392 0.81784267]
#  [0.4874217  0.21228144 0.35641828]
#  [0.47730661 0.81247561 0.84439812]
#  [0.47428863 0.5462064  0.98471136]
#  [0.60570902 0.01511992 0.48280053]
#  [0.74917778 0.9813467  0.43395103]
#  [0.61589292 0.97316028 0.56322247]
#  [0.85561398 0.75546231 0.00694593]]
# Type:  <class 'numpy.ndarray'>
#
# Panda's DataFrame:
#            A         B         C
# 0   0.554112  0.086379  0.130244
# 1   0.344524  0.532194  0.176493
# 2   0.230424  0.929775  0.170659
# 3   0.515756  0.653112  0.212376
# 4   0.038430  0.641063  0.652271
# 5   0.245228  0.589363  0.358070
# 6   0.139335  0.692967  0.839033
# 7   0.700788  0.947613  0.217729
# 8   0.941159  0.774276  0.082665
# 9   0.853139  0.288719  0.691460
# 10  0.450981  0.278842  0.888218
# 11  0.373264  0.813735  0.582122
# ...

# %%
import pandas as pd

#initialize a dataframe
df = pd.DataFrame(
	[[21, 72, 67],
	[23, 78, 69],
	[32, 74, 56],
	[52, 54, 76]],
	columns=['a', 'b', 'c'])

print('DataFrame\n----------\n', df)

#convert dataframe to numpy array
arr = df.to_numpy()

print('\nNumpy Array\n----------\n', arr)
# Out:
# DataFrame
# ----------
#      a   b   c
# 0  21  72  67
# 1  23  78  69
# 2  32  74  56
# 3  52  54  76
#
# Numpy Array
# ----------
#  [[21 72 67]
#  [23 78 69]
#  [32 74 56]
#  [52 54 76]]

# %%
import pandas as pd
import numpy as np

#initialize a dataframe
df = pd.DataFrame(
	[[21, 72, 67.1],
	[23, 78, 69.5],
	[32, 74, 56.6],
	[52, 54, 76.2]],
	columns=['a', 'b', 'c'])

print('DataFrame\n----------\n', df)
print('\nDataFrame datatypes :\n', df.dtypes)

#convert pandas dataframe to numpy array
arr = df.to_numpy()

print('\nNumpy Array\n----------\n', arr)
print('\nNumpy Array Datatype :', arr.dtype)
# Out:
# DataFrame
# ----------
#      a   b     c
# 0  21  72  67.1
# 1  23  78  69.5
# 2  32  74  56.6
# 3  52  54  76.2
#
# DataFrame datatypes :
#  a      int64
# b      int64
# c    float64
# dtype: object
#
# Numpy Array
# ----------
#  [[21.  72.  67.1]
#  [23.  78.  69.5]
#  [32.  74.  56.6]
#  [52.  54.  76.2]]
#
# Numpy Array Datatype : float64

# %%
df
# Out:
#     a   b     c
# 0  21  72  67.1
# 1  23  78  69.5
# 2  32  74  56.6
# 3  52  54  76.2

# %%
arr
# Out:
# array([[21. , 72. , 67.1],
#        [23. , 78. , 69.5],
#        [32. , 74. , 56.6],
#        [52. , 54. , 76.2]])

# %% [markdown]
# ##Reading and Writing CSV Files in Python with Pandas

# %%
import pandas as pd
t20_data = pd.read_csv('matches.csv')
t20_data.head()
# Out:
#    id    Season       city  ...         umpire1        umpire2 umpire3
# 0   1  IPL-2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2  IPL-2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3  IPL-2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4  IPL-2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5  IPL-2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
#Add Specific column name in data
import pandas as pd
col_names=['id','city','team1','team2','toss_winner']
t20_data = pd.read_csv('matches.csv', names=col_names, header=None)
t20_data.head(10)
# Out:
#                                                                                                                                                                                                                           id  ... toss_winner
# id Season   city      date       team1                       team2                       toss_winner                 toss_decision result dl_applied winner                      win_by_runs win_by_wickets  player_of_match  ...     umpire3
# 1  IPL-2017 Hyderabad 05-04-2017 Sunrisers Hyderabad         Royal Challengers Bangalore Royal Challengers Bangalore field         normal 0          Sunrisers Hyderabad         35          0                  Yuvraj Singh  ...         NaN
# 2  IPL-2017 Pune      06-04-2017 Mumbai Indians              Rising Pune Supergiant      Rising Pune Supergiant      field         normal 0          Rising Pune Supergiant      0           7                     SPD Smith  ...         NaN
# ...

# %%
t20_data.tail()
# Out:
#                                                                                                                                                         id  ...              toss_winner
# 11347 IPL-2019 Mumbai        05-05-2019 Kolkata Knight Riders Mumbai Indians      Mumbai Indians      field normal 0 Mumbai Indians      0 9     HH Pandya  ...                   S Ravi
# 11412 IPL-2019 Chennai       07-05-2019 Chennai Super Kings   Mumbai Indians      Chennai Super Kings bat   normal 0 Mumbai Indians      0 6      AS Yadav  ...                Ian Gould
# 11413 IPL-2019 Visakhapatnam 08-05-2019 Sunrisers Hyderabad   Delhi Capitals      Delhi Capitals      field normal 0 Delhi Capitals      0 2       RR Pant  ...                      NaN
# 11414 IPL-2019 Visakhapatnam 10-05-2019 Delhi Capitals        Chennai Super Kings Chennai Super Kings field normal 0 Chennai Super Kings 0 6  F du Plessis  ...  Chettithody Shamshuddin
# ...

# %%
t20_data.tail(20)
# Out:
#                                                                                                                                                                                             id  ...              toss_winner
# 11332 IPL-2019 Chennai       23-04-2019 Sunrisers Hyderabad         Chennai Super Kings         Chennai Super Kings         field normal    0 Chennai Super Kings         0  6       SR Watson  ...          Vineet Kulkarni
# 11333 IPL-2019 Bengaluru     24-04-2019 Royal Challengers Bangalore Kings XI Punjab             Kings XI Punjab             field normal    0 Royal Challengers Bangalore 17 0  AB de Villiers  ...               Rod Tucker
# 11334 IPL-2019 Kolkata       25-04-2019 Kolkata Knight Riders       Rajasthan Royals            Rajasthan Royals            field normal    0 Rajasthan Royals            0  3        VR Aaron  ...              Nitin Menon
# ...

# %%
t20_data.head()
# Out:
#                                                                                                                                                                                                                 id  ... toss_winner
# id Season   city      date       team1                  team2                       toss_winner                 toss_decision result dl_applied winner                 win_by_runs win_by_wickets  player_of_match  ...     umpire3
# 1  IPL-2017 Hyderabad 05-04-2017 Sunrisers Hyderabad    Royal Challengers Bangalore Royal Challengers Bangalore field         normal 0          Sunrisers Hyderabad    35          0                  Yuvraj Singh  ...         NaN
# 2  IPL-2017 Pune      06-04-2017 Mumbai Indians         Rising Pune Supergiant      Rising Pune Supergiant      field         normal 0          Rising Pune Supergiant 0           7                     SPD Smith  ...         NaN
# ...

# %%
t20_data.head(15)
# Out:
#                                                                                                                                                                                                                           id  ... toss_winner
# id Season   city      date       team1                       team2                       toss_winner                 toss_decision result dl_applied winner                      win_by_runs win_by_wickets  player_of_match  ...     umpire3
# 1  IPL-2017 Hyderabad 05-04-2017 Sunrisers Hyderabad         Royal Challengers Bangalore Royal Challengers Bangalore field         normal 0          Sunrisers Hyderabad         35          0                  Yuvraj Singh  ...         NaN
# 2  IPL-2017 Pune      06-04-2017 Mumbai Indians              Rising Pune Supergiant      Rising Pune Supergiant      field         normal 0          Rising Pune Supergiant      0           7                     SPD Smith  ...         NaN
# ...

# %%
t20_data.sample()
# Out:
#                                                                                                                                                           id  ... toss_winner
# 42 IPL-2017 Bangalore 05-05-2017 Kings XI Punjab Royal Challengers Bangalore Royal Challengers Bangalore field normal 0 Kings XI Punjab 19 0  Sandeep Sharma  ...         NaN
#
# [1 rows x 5 columns]

# %%
t20_data.sample(5)
# Out:
#                                                                                                                                                    id  ...     toss_winner
# 11139 IPL-2019 Mumbai    24-03-2019 Delhi Capitals      Mumbai Indians      Mumbai Indians      field normal 0 Delhi Capitals   37 0          RR Pant  ...        O Nandan
# 553   IPL-2015 Mumbai    03-05-2015 Rajasthan Royals    Delhi Daredevils    Delhi Daredevils    field normal 0 Rajasthan Royals 14 0        AM Rahane  ...             NaN
# 556   IPL-2015 Mumbai    05-05-2015 Delhi Daredevils    Mumbai Indians      Delhi Daredevils    bat   normal 0 Mumbai Indians   0  5  Harbhajan Singh  ...             NaN
# 461   IPL-2014 Abu Dhabi 18-04-2014 Sunrisers Hyderabad Rajasthan Royals    Rajasthan Royals    field normal 0 Rajasthan Royals 0  4        AM Rahane  ...             NaN
# ...

# %%
t20_data.head()
# Out:
#                                                                                                                                                                                                                 id  ... toss_winner
# id Season   city      date       team1                  team2                       toss_winner                 toss_decision result dl_applied winner                 win_by_runs win_by_wickets  player_of_match  ...     umpire3
# 1  IPL-2017 Hyderabad 05-04-2017 Sunrisers Hyderabad    Royal Challengers Bangalore Royal Challengers Bangalore field         normal 0          Sunrisers Hyderabad    35          0                  Yuvraj Singh  ...         NaN
# 2  IPL-2017 Pune      06-04-2017 Mumbai Indians         Rising Pune Supergiant      Rising Pune Supergiant      field         normal 0          Rising Pune Supergiant 0           7                     SPD Smith  ...         NaN
# ...

# %%
# Select specific columns of your dataframe

t20_data[['id','city']].head(5)
# Out:
#                                                                                                                                                                                                                 id                                       city
# id Season   city      date       team1                  team2                       toss_winner                 toss_decision result dl_applied winner                 win_by_runs win_by_wickets  player_of_match                                      venue
# 1  IPL-2017 Hyderabad 05-04-2017 Sunrisers Hyderabad    Royal Challengers Bangalore Royal Challengers Bangalore field         normal 0          Sunrisers Hyderabad    35          0                  Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# ...

# %%
import pandas as pd
t20_data = pd.read_csv('matches.csv')
t20_data.head()
# Out:
#    id    Season       city  ...         umpire1        umpire2 umpire3
# 0   1  IPL-2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2  IPL-2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3  IPL-2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4  IPL-2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5  IPL-2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
#Filter for specific values in your dataframe
t20_data['toss_winner'] == 'Royal Challengers Bangalore'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# Name: toss_winner, Length: 756, dtype: bool

# %%
#Filter for specific values in your dataframe
t20_data['winner'] == 'Royal Challengers Bangalore'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# Name: winner, Length: 756, dtype: bool

# %%
df = pd.read_csv("f500.csv")
df.head()
# Out:
#                     company  rank  ...  employees  total_stockholder_equity
# 0                   Walmart     1  ...    2300000                     77798
# 1                State Grid     2  ...     926067                    209456
# 2             Sinopec Group     3  ...     713288                    106523
# 3  China National Petroleum     4  ...    1512048                    301893
# 4              Toyota Motor     5  ...     364445                    157210
#
# [5 rows x 17 columns]

# %%
df = pd.read_csv("f500.csv", header = 0)
df.head()
# Out:
#                     company  rank  ...  employees  total_stockholder_equity
# 0                   Walmart     1  ...    2300000                     77798
# 1                State Grid     2  ...     926067                    209456
# 2             Sinopec Group     3  ...     713288                    106523
# 3  China National Petroleum     4  ...    1512048                    301893
# 4              Toyota Motor     5  ...     364445                    157210
#
# [5 rows x 17 columns]

# %%
df = pd.read_csv("f500.csv", header = 10)
df.head()
# Out:
#            Exxon Mobil  10  205004  ...  23   72700  167325
# 0             McKesson  11  198533  ...  23   64500   11095
# 1                   BP  12  186606  ...  23   74500   95286
# 2   UnitedHealth Group  13  184840  ...  21  230000   38274
# 3           CVS Health  14  177526  ...  22  204000   36830
# 4  Samsung Electronics  15  173957  ...  23  325000  154376
#
# [5 rows x 17 columns]

# %%
df = pd.read_csv("f500.csv", header = 0)
df.head()
# Out:
#                     company  rank  ...  employees  total_stockholder_equity
# 0                   Walmart     1  ...    2300000                     77798
# 1                State Grid     2  ...     926067                    209456
# 2             Sinopec Group     3  ...     713288                    106523
# 3  China National Petroleum     4  ...    1512048                    301893
# 4              Toyota Motor     5  ...     364445                    157210
#
# [5 rows x 17 columns]

# %%
#If you set index_col to 0, then the first column of the dataframe will become the row label. Notice how the row labels change.
df = pd.read_csv("f500.csv", index_col = 0)
df.head(5)
# Out:
#                           rank  revenues  ...  employees  total_stockholder_equity
# company                                   ...
# Walmart                      1    485873  ...    2300000                     77798
# State Grid                   2    315199  ...     926067                    209456
# Sinopec Group                3    267518  ...     713288                    106523
# China National Petroleum     4    262573  ...    1512048                    301893
# Toyota Motor                 5    254694  ...     364445                    157210
#
# [5 rows x 16 columns]

# %%
#load specific column 
df = pd.read_csv("f500.csv", usecols = ["company", "rank", "revenues"])
df.head()
# Out:
#                     company  rank  revenues
# 0                   Walmart     1    485873
# 1                State Grid     2    315199
# 2             Sinopec Group     3    267518
# 3  China National Petroleum     4    262573
# 4              Toyota Motor     5    254694

# %%
#Skip first 4 rows
df = pd.read_csv("f500.csv", skiprows = 4)
df.head(5)
# Out:
#   China National Petroleum  4  262573  ...  17  1512048  301893
# 0             Toyota Motor  5  254694  ...  23   364445  157210
# 1               Volkswagen  6  240264  ...  23   626715   97753
# 2        Royal Dutch Shell  7  240033  ...  23    89000  186646
# 3       Berkshire Hathaway  8  223604  ...  21   367700  283001
# 4                    Apple  9  215639  ...  15   116000  128249
#
# [5 rows x 17 columns]

# %%
#If you want to read a limited number of rows, instead of all the rows in a dataset, use nrows.
df = pd.read_csv("f500.csv", nrows = 4)
df.head(5)
# Out:
#                     company  rank  ...  employees  total_stockholder_equity
# 0                   Walmart     1  ...    2300000                     77798
# 1                State Grid     2  ...     926067                    209456
# 2             Sinopec Group     3  ...     713288                    106523
# 3  China National Petroleum     4  ...    1512048                    301893
#
# [4 rows x 17 columns]

# %%
#If you want to read a limited number of rows, instead of all the rows in a dataset, use nrows.
df = pd.read_csv("f500.csv", nrows = 2)
df.head(5)
# Out:
#       company  rank  ...  employees  total_stockholder_equity
# 0     Walmart     1  ...    2300000                     77798
# 1  State Grid     2  ...     926067                    209456
#
# [2 rows x 17 columns]

# %%
import pandas as pd
NewYork=pd.read_csv('NYC.csv')

# %%
NewYork.head()
# Out:
#      id  ... availability_365
# 0  2539  ...            365.0
# 1  2595  ...            355.0
# 2  3647  ...            365.0
# 3  3831  ...            194.0
# 4  5022  ...              0.0
#
# [5 rows x 16 columns]

# %%
NewYork.tail()
# Out:
#              id  ... availability_365
# 21918  17625485  ...            161.0
# 21919  17625707  ...              0.0
# 21920  17625824  ...              0.0
# 21921  17626236  ...             16.0
# 21922         1  ...              NaN
#
# [5 rows x 16 columns]

# %%
NewYork.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                           float64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                    float64
# number_of_reviews                 float64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count    float64
# availability_365                  float64
# dtype: object

# %%
NewYork.drop(columns='name')
#delete column continent
# Out:
#              id     host_id  ... calculated_host_listings_count availability_365
# 0          2539      2787.0  ...                            6.0            365.0
# 1          2595      2845.0  ...                            2.0            355.0
# 2          3647      4632.0  ...                            1.0            365.0
# 3          3831      4869.0  ...                            1.0            194.0
# 4          5022      7192.0  ...                            1.0              0.0
# ...         ...         ...  ...                            ...              ...
# 21918  17625485   7824337.0  ...                            2.0            161.0
# 21919  17625707   8314232.0  ...                            1.0              0.0
# 21920  17625824  79882333.0  ...                            1.0              0.0
# 21921  17626236  54637605.0  ...                            1.0             16.0
# 21922         1         NaN  ...                            NaN              NaN
#
# ...

# %%
NewYork.drop([0,1,2,3,4])
#delete top 5 rows
# Out:
#              id  ... availability_365
# 5          5099  ...            129.0
# 6          5121  ...              0.0
# 7          5178  ...            220.0
# 8          5203  ...              0.0
# 9          5238  ...            188.0
# ...         ...  ...              ...
# 21918  17625485  ...            161.0
# 21919  17625707  ...              0.0
# 21920  17625824  ...              0.0
# 21921  17626236  ...             16.0
# 21922         1  ...              NaN
#
# [21918 rows x 16 columns]

# %%
NewYork.mean()
# Out:
# id                                8.453310e+06
# host_id                           2.426045e+07
# latitude                          4.072959e+01
# longitude                        -7.395696e+01
# price                             1.513750e+02
# minimum_nights                    7.416522e+00
# number_of_reviews                 3.579870e+01
# reviews_per_month                 9.413612e-01
# calculated_host_listings_count    3.732643e+00
# availability_365                  1.035321e+02
# dtype: float64

# %%
NewYork.mean().shape
# Out:
# (10,)

# %%
NewYork.mean(axis=1)
# Out:
# 0        5.822885e+02
# 1        6.035150e+02
# 2        9.738741e+02
# 3        9.226365e+02
# 4        1.228095e+03
#              ...
# 21918    2.545012e+06
# 21919    2.594005e+06
# 21920    9.750817e+06
# 21921    7.226395e+06
# 21922    1.000000e+00
# Length: 21923, dtype: float64

# %%
NewYork.mean(axis=0)
# Out:
# id                                8.453310e+06
# host_id                           2.426045e+07
# latitude                          4.072959e+01
# longitude                        -7.395696e+01
# price                             1.513750e+02
# minimum_nights                    7.416522e+00
# number_of_reviews                 3.579870e+01
# reviews_per_month                 9.413612e-01
# calculated_host_listings_count    3.732643e+00
# availability_365                  1.035321e+02
# dtype: float64

# %%
import pandas as pd
runs=pd.read_csv('runrate.csv')

# %%
runs.head()
# Out:
#                      team  home_wins  ...  home_win_percentage  away_win_percentage
# 0  Rising Pune Supergiant          5  ...            62.500000            62.500000
# 1          Mumbai Indians         58  ...            57.425743            59.302326
# 2     Chennai Super Kings         51  ...            57.303371            65.333333
# 3          Delhi Capitals          3  ...            50.000000            70.000000
# 4     Sunrisers Hyderabad         30  ...            47.619048            62.222222
#
# [5 rows x 7 columns]

# %%
runs.home_wins.mean()
# Out:
# 23.928571428571427

# %%
runs.groupby('home_matches').	home_wins.mean()
#mean according to each continents
# Out:
# home_matches
# 6       3
# 7       2
# 8       5
# 14      1
# 20      6
# 43     18
# 63     30
# 67     29
# 72     25
# 83     34
# 85     35
# 89     51
# 91     38
# 101    58
# Name: home_wins, dtype: int64

# %%
runs.groupby(runs.team=='Mumbai Indians').mean()
# Out:
#        home_wins  away_wins  ...  home_win_percentage  away_win_percentage
# team                         ...
# False  21.307692  27.769231  ...            40.530888            55.287510
# True   58.000000  51.000000  ...            57.425743            59.302326
#
# [2 rows x 6 columns]

# %%
runs.groupby(runs.team=='Mumbai Indians').mean().plot(kind="bar")

# %%
runs.groupby(runs.team=='Royal Challengers Bangalore').mean().plot(kind="bar")

# %%
runs.groupby(runs.team=='Royal Challengers Bangalore').mean()
# Out:
#        home_wins  away_wins  ...  home_win_percentage  away_win_percentage
# team                         ...
# False  23.076923  27.923077  ...            41.780832            55.881616
# True   35.000000  49.000000  ...            41.176471            51.578947
#
# [2 rows x 6 columns]

# %%
runs.groupby(runs.team=='Royal Challengers Bangalore').mean().plot(kind="bar")

# %%
runs.groupby(runs.team=='Royal Challengers Bangalore').mean().plot()

# %%
runs
# Out:
#                            team  ...  away_win_percentage
# 0        Rising Pune Supergiant  ...            62.500000
# 1                Mumbai Indians  ...            59.302326
# 2           Chennai Super Kings  ...            65.333333
# 3                Delhi Capitals  ...            70.000000
# 4           Sunrisers Hyderabad  ...            62.222222
# 5              Rajasthan Royals  ...            57.500000
# 6               Deccan Chargers  ...            34.375000
# 7               Kings XI Punjab  ...            51.764706
# 8   Royal Challengers Bangalore  ...            51.578947
# 9         Kolkata Knight Riders  ...            61.052632
# 10             Delhi Daredevils  ...            47.191011
# 11                Pune Warriors  ...            23.076923
# 12         Kochi Tuskers Kerala  ...            57.142857
# 13                Gujarat Lions  ...            75.000000
#
# [14 rows x 7 columns]

# %%
runs.home_matches
# Out:
# 0       8
# 1     101
# 2      89
# 3       6
# 4      63
# 5      67
# 6      43
# 7      91
# 8      85
# 9      83
# 10     72
# 11     20
# 12      7
# 13     14
# Name: home_matches, dtype: int64

# %%
runs.tail()
# Out:
#                      team  home_wins  ...  home_win_percentage  away_win_percentage
# 9   Kolkata Knight Riders         34  ...            40.963855            61.052632
# 10       Delhi Daredevils         25  ...            34.722222            47.191011
# 11          Pune Warriors          6  ...            30.000000            23.076923
# 12   Kochi Tuskers Kerala          2  ...            28.571429            57.142857
# 13          Gujarat Lions          1  ...             7.142857            75.000000
#
# [5 rows x 7 columns]

# %%
pd.get_option('display.max_columns')
# Out:
# 0
